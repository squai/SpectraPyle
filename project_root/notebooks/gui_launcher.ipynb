# %% [markdown]
# # spectraPyle GUI
#
# This notebook generates, validates configuration files for spectraPyle, and launches the code.
#
# Mandatory actions -> (*)
# Contact: Salvatore Quai (salvatore.quai@unibo.it)
#
# (Version: 1.0.0)

# %%
from gui import start
start()
